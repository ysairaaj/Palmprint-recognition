# %% [markdown]
# # General functions along with localization - network

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16
import tensorflow.keras.backend as K

# %%
IMGSIZE = (224, 224 ,3)

# %%
OUT_IMG_SIZE = (150 ,150 ,3)

# %%
IMG_PIXEL_RATIO = int(IMGSIZE[0]/OUT_IMG_SIZE[0])

# %%
Input_Layer = layers.Input(shape = IMGSIZE)

# %%
#BATCH_SIZE = 2

# %%
### Localization network architecture ###
def get_Localization_net(trainable = False):
    """ This is the localization network . It uses VGG16 network , prtrained on Imagenet dataset and it generates  
    parameters for transformations
    Input
    -----
    - Input Layer (added by default)
    Returns
    -------
    - 3D-Tensor of dimensions (B , 2 ,3)
    """
    output_bias = tf.keras.initializers.Constant([1, 0, 0, 0, 1, 0])
    #vgg = VGG16(include_top =False ,weights ='imagenet' ,input_shape = IMGSIZE )
    #vgg.trainable = trainable
    model = tf.keras.Sequential([
       layers.Conv2D(8, kernel_size=7, input_shape=(IMGSIZE[0], IMGSIZE[0], 3), 
                      activation="relu", kernel_initializer="he_normal"),
        layers.MaxPool2D(strides=2),
        layers.Conv2D(10, kernel_size=5, activation="relu", kernel_initializer="he_normal"),
        layers.MaxPool2D(strides=2),
       layers.Dense(32 , activation = keras.layers.LeakyReLU(0.3),kernel_initializer="he_normal"), 
       layers.Dense(6 , kernel_initializer="zeros", bias_initializer=output_bias) 
    ])
    #a = layers.Flatten()(vgg.output)
    #a = layers.Dense(128 , activation = keras.layers.LeakyReLU(0.3),kernel_initializer="he_normal")(a)
    #a = layers.Dense(64 , activation = keras.layers.LeakyReLU(0.3),kernel_initializer="he_normal")(a)
    #a = layers.Dense(32 , activation = keras.layers.LeakyReLU(0.3),kernel_initializer="he_normal")(a)
    #a = layers.Dense(6 , kernel_initializer="zeros", bias_initializer=output_bias)(a)
    #a = layers.Reshape((2, 3), input_shape=(6,))(a)
    return model

# %%
get_Localization_net(trainable = False).summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 218, 218, 8)       1184
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 109, 109, 8)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 105, 105, 10)      2010
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 52, 52, 10)        0
# _________________________________________________________________
# dense_28 (Dense)             (None, 52, 52, 32)        352
# _________________________________________________________________
# dense_29 (Dense)             (None, 52, 52, 6)         198
# =================================================================
# Total params: 3,744
# Trainable params: 3,744
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_localization_network():
    localization = tf.keras.Sequential([
        layers.Conv2D(8, kernel_size=7, input_shape=(IMGSIZE[0], IMGSIZE[0], 3), 
                      activation="relu", kernel_initializer="he_normal"),
        layers.MaxPool2D(strides=2),
        layers.Conv2D(10, kernel_size=5, activation="relu", kernel_initializer="he_normal"),
        layers.MaxPool2D(strides=2)
    ])
    return localization
def get_affine_params():
    output_bias = tf.keras.initializers.Constant([1, 0, 0, 0, 1, 0])
    fc_loc = tf.keras.Sequential([
        layers.Dense(32, activation="relu", kernel_initializer="he_normal"),
        layers.Dense(3 * 2, kernel_initializer="zeros", bias_initializer=output_bias)
    ])

    return fc_loc

# %% [markdown]
# # Spatial Transformation utilities

# %%
##pixel value generator##
def get_pixel_value(img, x, y):
    """
    Utility function to get pixel value for coordinate
    vectors x and y from a  4D tensor image.
    Input
    -----
    - img: tensor of shape (B, H, W, C)
    - x: flattened tensor of shape (B*H*W,)
    - y: flattened tensor of shape (B*H*W,)
    Returns
    -------
    - output: tensor of shape (B, H, W, C)
    """
    shape = tf.shape(x)
    batch_size = shape[0]
    height = shape[1]
    width = shape[2]

    batch_idx = tf.range(0, batch_size)
    batch_idx = tf.reshape(batch_idx, (batch_size, 1, 1))
    b = tf.tile(batch_idx, (1, height, width))

    indices = tf.stack([b, y, x], 3)

    return tf.gather_nd(img, indices)

# %%
## transformation grid generator##
def affine_grid_generator(height, width, theta):
    """
    This function returns a sampling grid, which when
    used with the bilinear sampler on the input feature
    map, will create an output feature map that is an
    affine transformation [1] of the input feature map.
    Input
    -----
    - height: desired height of grid/output. Used
      to downsample or upsample.
    - width: desired width of grid/output. Used
      to downsample or upsample.
    - theta: affine transform matrices of shape (num_batch, 2, 3).
      For each image in the batch, we have 6 theta parameters of
      the form (2x3) that define the affine transformation T.
    Returns
    -------
    - normalized grid (-1, 1) of shape (num_batch, 2, H, W).
      The 2nd dimension has 2 components: (x, y) which are the
      sampling points of the original image for each point in the
      target image.
    Note
    ----
    [1]: the affine transformation allows cropping, translation,
         and isotropic scaling.
    """
    num_batch = tf.shape(theta)[0]

    # create normalized 2D grid
    x = tf.linspace(-1.0, 1.0, width)
    y = tf.linspace(-1.0, 1.0, height)
    x_t, y_t = tf.meshgrid(x, y)

    # flatten
    x_t_flat = tf.reshape(x_t, [-1])
    y_t_flat = tf.reshape(y_t, [-1])

    # reshape to [x_t, y_t , 1] - (homogeneous form)
    ones = tf.ones_like(x_t_flat)
    sampling_grid = tf.stack([x_t_flat, y_t_flat, ones])

    # repeat grid num_batch times
    sampling_grid = tf.expand_dims(sampling_grid, axis=0)
    sampling_grid = tf.tile(sampling_grid, tf.stack([num_batch, 1, 1]))

    # cast to float32 (required for matmul)
    theta = tf.cast(theta, 'float32')
    sampling_grid = tf.cast(sampling_grid, 'float32')

    # transform the sampling grid - batch multiply
    batch_grids = tf.matmul(theta, sampling_grid)
    # batch grid has shape (num_batch, 2, H*W)

    # reshape to (num_batch,2, H, W)
    batch_grids = tf.reshape(batch_grids, [num_batch, 2, height, width])

    return batch_grids

# %%
def bilinear_sampler(img, x, y):
    """
    Performs bilinear sampling of the input images according to the
    normalized coordinates provided by the sampling grid. Note that
    the sampling is done identically for each channel of the input.
    To test if the function works properly, output image should be
    identical to input image when theta is initialized to identity
    transform.
    Input
    -----
    - img: batch of images in (B, H, W, C) layout.
    - grid: x, y which is the output of affine_grid_generator.
    Returns
    -------
    - out: interpolated images according to grids. Same size as grid.
    """
    H = tf.shape(img)[1]
    W = tf.shape(img)[2]
    max_y = tf.cast(H - 1, 'int32')
    max_x = tf.cast(W - 1, 'int32')
    zero = tf.zeros([], dtype='int32')

    # rescale x and y to [0, W-1/H-1]
    x = tf.cast(x, 'float32')
    y = tf.cast(y, 'float32')
    x = 0.5 * ((x + 1.0) * tf.cast(max_x-1, 'float32'))
    y = 0.5 * ((y + 1.0) * tf.cast(max_y-1, 'float32'))

    # grab 4 nearest corner points for each (x_i, y_i)
    x0 = tf.cast(tf.floor(x), 'int32')
    x1 = x0 + 1
    y0 = tf.cast(tf.floor(y), 'int32')
    y1 = y0 + 1

    # clip to range [0, H-1/W-1] to not violate img boundaries
    x0 = tf.clip_by_value(x0, zero, max_x)
    x1 = tf.clip_by_value(x1, zero, max_x)
    y0 = tf.clip_by_value(y0, zero, max_y)
    y1 = tf.clip_by_value(y1, zero, max_y)

    # get pixel value at corner coords
    Ia = get_pixel_value(img, x0, y0)
    Ib = get_pixel_value(img, x0, y1)
    Ic = get_pixel_value(img, x1, y0)
    Id = get_pixel_value(img, x1, y1)

    # recast as float for delta calculation
    x0 = tf.cast(x0, 'float32')
    x1 = tf.cast(x1, 'float32')
    y0 = tf.cast(y0, 'float32')
    y1 = tf.cast(y1, 'float32')

    # calculate deltas
    wa = (x1-x) * (y1-y)
    wb = (x1-x) * (y-y0)
    wc = (x-x0) * (y1-y)
    wd = (x-x0) * (y-y0)

    # add dimension for addition
    wa = tf.expand_dims(wa, axis=3)
    wb = tf.expand_dims(wb, axis=3)
    wc = tf.expand_dims(wc, axis=3)
    wd = tf.expand_dims(wd, axis=3)

    # compute output
    out = tf.add_n([wa*Ia, wb*Ib, wc*Ic, wd*Id])

    return out

# %% [markdown]
# # Spatial Transformation Network forward function

# %%
def stn(x):
    localization = get_localization_network()
    fc_loc = get_affine_params()
    
    xs = localization(x)
    xs = tf.reshape(xs, (-1, 10 * 3 * 3 ))
    theta = fc_loc(xs)
    theta = tf.reshape(theta, (-1, 2, 3))
    
    grid = affine_grid_generator(OUT_IMG_SIZE[0], OUT_IMG_SIZE[1], theta)
    x_s = grid[:, 0, :, :]
    y_s = grid[:, 1, :, :]
    x = bilinear_sampler(x, x_s, y_s)

    return x

# %%
def get_training_model(use_stn=True):
    inputs = layers.Input(shape = (IMGSIZE[0], IMGSIZE[0], 3))
    if use_stn:
        outputs = stn(inputs)
    else:
        outputs = inputs
    return tf.keras.Model(inputs, outputs)

# %%
stn_model = get_training_model()
stn_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 52, 52, 10)   3194        input_8[0][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None, 90)           0           sequential_2[0][0]
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 6)            3110        tf.reshape_7[0][0]
# __________________________________________________________________________________________________
# tf.reshape_8 (TFOpLambda)       (None, 2, 3)         0           sequential_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_7 (TFOpLambd (3,)                 0           tf.reshape_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_17 (Sl ()                   0           tf.compat.v1.shape_7[0][0]
# __________________________________________________________________________________________________
# tf.stack_5 (TFOpLambda)         (3,)                 0           tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.tile_5 (TFOpLambda)          (None, 3, 22500)     0           tf.stack_5[0][0]
# __________________________________________________________________________________________________
# tf.cast_14 (TFOpLambda)         (None, 2, 3)         0           tf.reshape_8[0][0]
# __________________________________________________________________________________________________
# tf.cast_15 (TFOpLambda)         (None, 3, 22500)     0           tf.tile_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_9 (TFOpLambd (4,)                 0           input_8[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_1 (TFOpLambda) (None, 2, 22500)     0           tf.cast_14[0][0]
#                                                                  tf.cast_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_21 (Sl ()                   0           tf.compat.v1.shape_9[0][0]
# __________________________________________________________________________________________________
# tf.reshape_9 (TFOpLambda)       (None, 2, 150, 150)  0           tf.linalg.matmul_1[0][0]
#                                                                  tf.__operators__.getitem_17[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_13 (TFOpLambda ()                   0           tf.__operators__.getitem_21[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_18 (Sl (None, 150, 150)     0           tf.reshape_9[0][0]
# __________________________________________________________________________________________________
# tf.cast_17 (TFOpLambda)         ()                   0           tf.math.subtract_13[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_8 (TFOpLambd (4,)                 0           input_8[0][0]
# __________________________________________________________________________________________________
# tf.cast_18 (TFOpLambda)         (None, 150, 150)     0           tf.__operators__.getitem_18[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_14 (TFOpLambda ()                   0           tf.cast_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_20 (Sl ()                   0           tf.compat.v1.shape_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 150, 150)     0           tf.cast_18[0][0]
# __________________________________________________________________________________________________
# tf.cast_20 (TFOpLambda)         ()                   0           tf.math.subtract_14[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_12 (TFOpLambda ()                   0           tf.__operators__.getitem_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 150, 150)     0           tf.__operators__.add_4[0][0]
#                                                                  tf.cast_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_19 (Sl (None, 150, 150)     0           tf.reshape_9[0][0]
# __________________________________________________________________________________________________
# tf.cast_16 (TFOpLambda)         ()                   0           tf.math.subtract_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 150, 150)     0           tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# tf.cast_19 (TFOpLambda)         (None, 150, 150)     0           tf.__operators__.getitem_19[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_15 (TFOpLambda ()                   0           tf.cast_16[0][0]
# __________________________________________________________________________________________________
# tf.math.floor_2 (TFOpLambda)    (None, 150, 150)     0           tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 150, 150)     0           tf.cast_19[0][0]
# __________________________________________________________________________________________________
# tf.cast_21 (TFOpLambda)         ()                   0           tf.math.subtract_15[0][0]
# __________________________________________________________________________________________________
# tf.cast_22 (TFOpLambda)         (None, 150, 150)     0           tf.math.floor_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 150, 150)     0           tf.__operators__.add_5[0][0]
#                                                                  tf.cast_21[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 150, 150)     0           tf.cast_22[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 150, 150)     0           tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_5 (TFOpLambda) (None, 150, 150)     0           tf.__operators__.add_6[0][0]
#                                                                  tf.cast_17[0][0]
# __________________________________________________________________________________________________
# tf.math.floor_3 (TFOpLambda)    (None, 150, 150)     0           tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_4 (TFOpLambda) (None, 150, 150)     0           tf.cast_22[0][0]
#                                                                  tf.cast_17[0][0]
# __________________________________________________________________________________________________
# tf.cast_23 (TFOpLambda)         (None, 150, 150)     0           tf.math.floor_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_10 (TFOpLamb (3,)                 0           tf.clip_by_value_4[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_11 (TFOpLamb (3,)                 0           tf.clip_by_value_4[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_12 (TFOpLamb (3,)                 0           tf.clip_by_value_5[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.shape_13 (TFOpLamb (3,)                 0           tf.clip_by_value_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 150, 150)     0           tf.cast_23[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_22 (Sl ()                   0           tf.compat.v1.shape_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_25 (Sl ()                   0           tf.compat.v1.shape_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_28 (Sl ()                   0           tf.compat.v1.shape_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_31 (Sl ()                   0           tf.compat.v1.shape_13[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_7 (TFOpLambda) (None, 150, 150)     0           tf.__operators__.add_7[0][0]
#                                                                  tf.cast_16[0][0]
# __________________________________________________________________________________________________
# tf.range_4 (TFOpLambda)         (None,)              0           tf.__operators__.getitem_22[0][0]
# __________________________________________________________________________________________________
# tf.clip_by_value_6 (TFOpLambda) (None, 150, 150)     0           tf.cast_23[0][0]
#                                                                  tf.cast_16[0][0]
# __________________________________________________________________________________________________
# tf.range_5 (TFOpLambda)         (None,)              0           tf.__operators__.getitem_25[0][0]
# __________________________________________________________________________________________________
# tf.range_6 (TFOpLambda)         (None,)              0           tf.__operators__.getitem_28[0][0]
# __________________________________________________________________________________________________
# tf.range_7 (TFOpLambda)         (None,)              0           tf.__operators__.getitem_31[0][0]
# __________________________________________________________________________________________________
# tf.cast_25 (TFOpLambda)         (None, 150, 150)     0           tf.clip_by_value_5[0][0]
# __________________________________________________________________________________________________
# tf.cast_27 (TFOpLambda)         (None, 150, 150)     0           tf.clip_by_value_7[0][0]
# __________________________________________________________________________________________________
# tf.reshape_10 (TFOpLambda)      (None, 1, 1)         0           tf.range_4[0][0]
#                                                                  tf.__operators__.getitem_22[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_23 (Sl ()                   0           tf.compat.v1.shape_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_24 (Sl ()                   0           tf.compat.v1.shape_10[0][0]
# __________________________________________________________________________________________________
# tf.cast_26 (TFOpLambda)         (None, 150, 150)     0           tf.clip_by_value_6[0][0]
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 1, 1)         0           tf.range_5[0][0]
#                                                                  tf.__operators__.getitem_25[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_26 (Sl ()                   0           tf.compat.v1.shape_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_27 (Sl ()                   0           tf.compat.v1.shape_11[0][0]
# __________________________________________________________________________________________________
# tf.cast_24 (TFOpLambda)         (None, 150, 150)     0           tf.clip_by_value_4[0][0]
# __________________________________________________________________________________________________
# tf.reshape_12 (TFOpLambda)      (None, 1, 1)         0           tf.range_6[0][0]
#                                                                  tf.__operators__.getitem_28[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_29 (Sl ()                   0           tf.compat.v1.shape_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_30 (Sl ()                   0           tf.compat.v1.shape_12[0][0]
# __________________________________________________________________________________________________
# tf.reshape_13 (TFOpLambda)      (None, 1, 1)         0           tf.range_7[0][0]
#                                                                  tf.__operators__.getitem_31[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_32 (Sl ()                   0           tf.compat.v1.shape_13[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_33 (Sl ()                   0           tf.compat.v1.shape_13[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_16 (TFOpLambda (None, 150, 150)     0           tf.cast_25[0][0]
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_17 (TFOpLambda (None, 150, 150)     0           tf.cast_27[0][0]
#                                                                  tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# tf.tile_6 (TFOpLambda)          (None, None, None)   0           tf.reshape_10[0][0]
#                                                                  tf.__operators__.getitem_23[0][0]
#                                                                  tf.__operators__.getitem_24[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_18 (TFOpLambda (None, 150, 150)     0           tf.cast_25[0][0]
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_19 (TFOpLambda (None, 150, 150)     0           tf.math.multiply_15[0][0]
#                                                                  tf.cast_26[0][0]
# __________________________________________________________________________________________________
# tf.tile_7 (TFOpLambda)          (None, None, None)   0           tf.reshape_11[0][0]
#                                                                  tf.__operators__.getitem_26[0][0]
#                                                                  tf.__operators__.getitem_27[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_20 (TFOpLambda (None, 150, 150)     0           tf.math.multiply_13[0][0]
#                                                                  tf.cast_24[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_21 (TFOpLambda (None, 150, 150)     0           tf.cast_27[0][0]
#                                                                  tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# tf.tile_8 (TFOpLambda)          (None, None, None)   0           tf.reshape_12[0][0]
#                                                                  tf.__operators__.getitem_29[0][0]
#                                                                  tf.__operators__.getitem_30[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_22 (TFOpLambda (None, 150, 150)     0           tf.math.multiply_13[0][0]
#                                                                  tf.cast_24[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_23 (TFOpLambda (None, 150, 150)     0           tf.math.multiply_15[0][0]
#                                                                  tf.cast_26[0][0]
# __________________________________________________________________________________________________
# tf.tile_9 (TFOpLambda)          (None, None, None)   0           tf.reshape_13[0][0]
#                                                                  tf.__operators__.getitem_32[0][0]
#                                                                  tf.__operators__.getitem_33[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_16 (TFOpLambda (None, 150, 150)     0           tf.math.subtract_16[0][0]
#                                                                  tf.math.subtract_17[0][0]
# __________________________________________________________________________________________________
# tf.stack_6 (TFOpLambda)         (None, 150, 150, 3)  0           tf.tile_6[0][0]
#                                                                  tf.clip_by_value_6[0][0]
#                                                                  tf.clip_by_value_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_17 (TFOpLambda (None, 150, 150)     0           tf.math.subtract_18[0][0]
#                                                                  tf.math.subtract_19[0][0]
# __________________________________________________________________________________________________
# tf.stack_7 (TFOpLambda)         (None, 150, 150, 3)  0           tf.tile_7[0][0]
#                                                                  tf.clip_by_value_7[0][0]
#                                                                  tf.clip_by_value_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_18 (TFOpLambda (None, 150, 150)     0           tf.math.subtract_20[0][0]
#                                                                  tf.math.subtract_21[0][0]
# __________________________________________________________________________________________________
# tf.stack_8 (TFOpLambda)         (None, 150, 150, 3)  0           tf.tile_8[0][0]
#                                                                  tf.clip_by_value_6[0][0]
#                                                                  tf.clip_by_value_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_19 (TFOpLambda (None, 150, 150)     0           tf.math.subtract_22[0][0]
#                                                                  tf.math.subtract_23[0][0]
# __________________________________________________________________________________________________
# tf.stack_9 (TFOpLambda)         (None, 150, 150, 3)  0           tf.tile_9[0][0]
#                                                                  tf.clip_by_value_7[0][0]
#                                                                  tf.clip_by_value_5[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_4 (TFOpLambda)   (None, 150, 150, 1)  0           tf.math.multiply_16[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_nd_4 (TFOpL (None, 150, 150, 3)  0           input_8[0][0]
#                                                                  tf.stack_6[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_5 (TFOpLambda)   (None, 150, 150, 1)  0           tf.math.multiply_17[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_nd_5 (TFOpL (None, 150, 150, 3)  0           input_8[0][0]
#                                                                  tf.stack_7[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_6 (TFOpLambda)   (None, 150, 150, 1)  0           tf.math.multiply_18[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_nd_6 (TFOpL (None, 150, 150, 3)  0           input_8[0][0]
#                                                                  tf.stack_8[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_7 (TFOpLambda)   (None, 150, 150, 1)  0           tf.math.multiply_19[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_nd_7 (TFOpL (None, 150, 150, 3)  0           input_8[0][0]
#                                                                  tf.stack_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_20 (TFOpLambda (None, 150, 150, 3)  0           tf.expand_dims_4[0][0]
#                                                                  tf.compat.v1.gather_nd_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_21 (TFOpLambda (None, 150, 150, 3)  0           tf.expand_dims_5[0][0]
#                                                                  tf.compat.v1.gather_nd_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_22 (TFOpLambda (None, 150, 150, 3)  0           tf.expand_dims_6[0][0]
#                                                                  tf.compat.v1.gather_nd_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_23 (TFOpLambda (None, 150, 150, 3)  0           tf.expand_dims_7[0][0]
#                                                                  tf.compat.v1.gather_nd_7[0][0]
# __________________________________________________________________________________________________
# tf.math.add_n_1 (TFOpLambda)    (None, 150, 150, 3)  0           tf.math.multiply_20[0][0]
#                                                                  tf.math.multiply_21[0][0]
#                                                                  tf.math.multiply_22[0][0]
#                                                                  tf.math.multiply_23[0][0]
# ==================================================================================================
# Total params: 6,304
# Trainable params: 6,304
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def lambda_function(lst):
    Input_Layer = lst[0]
    trans_matrix = lst[1]
    trans_matrix = tf.reshape(trans_matrix, (-1, 2, 3))
    grid = affine_grid_generator(OUT_IMG_SIZE[0],OUT_IMG_SIZE[1], trans_matrix)
    x_s = grid[:, 0, :, :]
    y_s = grid[:, 1, :, :]
    x = bilinear_sampler(Input_layer, x_s, y_s)
    return x

# %%
def get_STN(Input_layer = Input_Layer):
    """
    This the model generator function.
    Input
    -----
    - None
    Returns
    -------
    - tensorflow.keras.model (Trainable)
    """
    trans_matrix = get_Localization_net(trainable = False)
    x = layers.Lambda(lambda_function)([Input_layer , trans_matrix ])
    #grid = affine_grid_generator(OUT_IMG_SIZE[0],OUT_IMG_SIZE[1], trans_matrix)
    #x_s = grid[:, 0, :, :]
    #y_s = grid[:, 1, :, :]
    #x = bilinear_sampler(Input_layer, x_s, y_s)
    return x

# %%
stn = keras.Model(inputs = Input_Layer ,outputs = get_STN(Input_layer = Input_Layer))
stn.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape, allow_broadcast)
#     548     try:
# --> 549       str_values = [compat.as_bytes(x) for x in proto_values]
#     550     except TypeError:
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\tensor_util.py in <listcomp>(.0)
#     548     try:
# --> 549       str_values = [compat.as_bytes(x) for x in proto_values]
#     550     except TypeError:
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\util\compat.py in as_bytes(bytes_or_text, encoding)
#      85   else:
# ---> 86     raise TypeError('Expected binary or unicode string, got %r' %
#      87                     (bytes_or_text,))
#
# TypeError: Expected binary or unicode string, got <tensorflow.python.keras.engine.sequential.Sequential object at 0x00000221E1D07E20>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2192/345673282.py in <module>
# ----> 1 stn = keras.Model(inputs = Input_Layer ,outputs = get_STN(Input_layer = Input_Layer))
#       2 stn.summary()
#
# ~\AppData\Local\Temp/ipykernel_2192/2793475521.py in get_STN(Input_layer)
#      10     """
#      11     trans_matrix = get_Localization_net(trainable = False)
# ---> 12     x = layers.Lambda(lambda_function)([Input_layer , trans_matrix ])
#      13     #grid = affine_grid_generator(OUT_IMG_SIZE[0],OUT_IMG_SIZE[1], trans_matrix)
#      14     #x_s = grid[:, 0, :, :]
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     994     # >> model = tf.keras.Model(inputs, outputs)
#     995     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 996       return self._functional_construction_call(inputs, args, kwargs,
#     997                                                 input_list)
#     998
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1132         layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1133       # Check input assumptions set after layer building, e.g. input shape.
# -> 1134       outputs = self._keras_tensor_symbolic_call(
#    1135           inputs, input_masks, args, kwargs)
#    1136
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     865       return nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     866     else:
# --> 867       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     868
#     869   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     905           self._maybe_build(inputs)
#     906           inputs = self._maybe_cast_inputs(inputs)
# --> 907           outputs = call_fn(inputs, *args, **kwargs)
#     908
#     909         self._handle_activity_regularization(inputs, outputs)
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\layers\core.py in call(self, inputs, mask, training)
#     923     with backprop.GradientTape(watch_accessed_variables=True) as tape,\
#     924         variable_scope.variable_creator_scope(_variable_creator):
# --> 925       result = self.function(inputs, **kwargs)
#     926     self._check_variables(created_variables, tape.watched_variables())
#     927     return result
#
# ~\AppData\Local\Temp/ipykernel_2192/1992031049.py in lambda_function(lst)
#       2     Input_Layer = lst[0]
#       3     trans_matrix = lst[1]
# ----> 4     trans_matrix = tf.reshape(trans_matrix, (-1, 2, 3))
#       5     grid = affine_grid_generator(OUT_IMG_SIZE[0],OUT_IMG_SIZE[1], trans_matrix)
#       6     x_s = grid[:, 0, :, :]
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\array_ops.py in reshape(tensor, shape, name)
#     194     A `Tensor`. Has the same type as `tensor`.
#     195   """
# --> 196   result = gen_array_ops.reshape(tensor, shape, name)
#     197   tensor_util.maybe_set_static_shape(result, shape)
#     198   return result
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in reshape(tensor, shape, name)
#    8400       pass  # Add nodes to the TensorFlow graph.
#    8401   # Add nodes to the TensorFlow graph.
# -> 8402   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    8403         "Reshape", tensor=tensor, shape=shape, name=name)
#    8404   _result = _outputs[:]
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     523         except TypeError as err:
#     524           if dtype is None:
# --> 525             raise err
#     526           else:
#     527             raise TypeError(
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     515                   preferred_dtype=default_dtype)
#     516           else:
# --> 517             values = ops.convert_to_tensor(
#     518                 values,
#     519                 name=input_arg.name,
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     344                                          as_ref=False):
#     345   _ = as_ref
# --> 346   return constant(v, dtype=dtype, name=name)
#     347
#     348
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     286   tensor_value = attr_value_pb2.AttrValue()
#     287   tensor_value.tensor.CopyFrom(
# --> 288       tensor_util.make_tensor_proto(
#     289           value, dtype=dtype, shape=shape, verify_shape=verify_shape,
#     290           allow_broadcast=allow_broadcast))
#
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape, allow_broadcast)
#     549       str_values = [compat.as_bytes(x) for x in proto_values]
#     550     except TypeError:
# --> 551       raise TypeError("Failed to convert object of type %s to Tensor. "
#     552                       "Contents: %s. Consider casting elements to a "
#     553                       "supported type." % (type(values), values))
#
# TypeError: Failed to convert object of type <class 'tensorflow.python.keras.engine.sequential.Sequential'> to Tensor. Contents: <tensorflow.python.keras.engine.sequential.Sequential object at 0x00000221E1D07E20>. Consider casting elements to a supported type.

# %%
trans_matrix = get_Localization_net(trainable = False ,Input_Layer = Input_Layer)
trans_matrix.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               3211392
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 17,936,614
# Trainable params: 3,221,926
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
## Testing ##
model = get_Localization_net(trainable = False)
#x = tf.random.normal((1,IMGSIZE[0] ,IMGSIZE[1],IMGSIZE[2]))
#print(x.shape)
#y = model(x)
#print(y.shape)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               3211392
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 17,936,614
# Trainable params: 3,221,926
# Non-trainable params: 14,714,688
# _________________________________________________________________
